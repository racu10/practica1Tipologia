# %%
import missingno as msno
import pandas as pd

# %%
data = pd.read_csv('cocacola.csv', ',')
msno.matrix(data) # Visulualización de los datos si tenemos Nones

# %%
msno.dendrogram(data) # Mapa de correlación de las variables
